# %%
pip install pandas matplotlib

# %%
# !sh test5Sweep.sh 0.0014 0.0024 0.0001 0.50 0.55 0.05
# Out:
# Parameters are:
#
# R values :  0.0014 0.0024 0.0001
# A values :  0.50 0.55 0.05
#
#
# Running simulations...
#
# Experiment:  0.0014 0.50
#
# Experiment:  0.0014 0.55
#
# Experiment:  0.0015 0.50
#
# Experiment:  0.0015 0.55
#
# Experiment:  0.0016 0.50
#
# Experiment:  0.0016 0.55
#
# Experiment:  0.0017 0.50
#
# Experiment:  0.0017 0.55
#
# Experiment:  0.0018 0.50
#
# Experiment:  0.0018 0.55
#
# Experiment:  0.0019 0.50
#
# Experiment:  0.0019 0.55
#
# Experiment:  0.0020 0.50
#
# Experiment:  0.0020 0.55
#
# Experiment:  0.0021 0.50
#
# Experiment:  0.0021 0.55
#
# Experiment:  0.0022 0.50
#
# Experiment:  0.0022 0.55
#
# Experiment:  0.0023 0.50
#
# Experiment:  0.0023 0.55
#
# Experiment:  0.0024 0.50
#
# Experiment:  0.0024 0.55

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_file_path = "/FOP/Practical Test 5/test5sweep_2024-10-23_12.08.38/0.0020_0.50.csv"
data = pd.read_csv(csv_file_path)

plt.plot(data['Susceptible'], label='Susceptible')
plt.plot(data['\tRecovered'], label='Recovered')
plt.plot(data['\tInfected'], label='Infected')

plt.legend()
plt.show()

# %%
# !rm -rf /test5sweep_2024-10-23_12.08.38
